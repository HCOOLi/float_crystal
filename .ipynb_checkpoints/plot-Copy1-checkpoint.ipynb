# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
1.5/0.8
# Out:
# 1.875

# %%
for Ep2 in [0.4,0.2]:
    for Ee2e in [4,6,8]:
        T=[]
        Ep12_list=[]
        for Ep12 in np.arange(0.4,1.3,0.2):
            data = pd.read_csv("/home/hcooh/fastdata/IC_stepheating10/Ep2=%gEp12=%gEe2e=%d/crystility"%(Ep2,Ep12,Ee2e),header=None,sep="\t",names=["T","C"])
            Ep12_list.append(Ep12)
            T.append(data["T"][data.diff()["C"].idxmin()])
            print("%g"%Ee2e,"%g"%Ep12,data["T"][data.diff()["C"].idxmin()] )
#         print("%g"%(0.3*i+2.5*j))
        plt.plot(Ep12_list,T,label="Ee2e=%g"%Ee2e)
        #plt.title("stepcool: Ee2e=%g"%i)
        plt.xlabel("Ep12")
        plt.ylabel("Tm")
    plt.legend()
    plt.show()
#         5*Ep1()
    #     plt.plot(data["T"],data["C"])
#     plt.show()
# Out:
# 4 0.4 2.5
# 4 0.6 2.85
# 4 0.8 3.2
# 4 1 3.65
# 4 1.2 4.0
# 6 0.4 3.1
# 6 0.6 3.25
# 6 0.8 3.65
# 6 1 4.05
# 6 1.2 4.4
# 8 0.4 3.85
# 8 0.6 3.85
# 8 0.8 4.1
# 8 1 4.45
# 8 1.2 4.85
# 4 0.4 2.2
# 4 0.6 2.6
# 4 0.8 3.05
# 4 1 3.45
# 4 1.2 4.0
# 6 0.4 2.65
# 6 0.6 3.05
# 6 0.8 3.45
# 6 1 3.85
# 6 1.2 4.25
# 8 0.4 3.3
# 8 0.6 3.4
# 8 0.8 3.8
# 8 1 4.25
# 8 1.2 4.65

# %%
for Ep2 in [0.4,0.2]:

    for Ee2e in [4,6,8,12]:
        T=[]
        Ep12_list=[]
        for Ep12 in np.arange(0.4,1.3,0.2):
            
            try:
                data = pd.read_csv("/home/hcooh/fastdata/IC_stepcoolingless/Ep2=%gEp12=%gEe2e=%d/crystility"%(Ep2,Ep12,Ee2e),header=None,sep="\t",names=["T","C"])
                Ep12_list.append(Ep12)
                T.append(data["T"][data.diff()["C"].idxmin()])
                print("%g"%Ee2e,"%g"%Ep12,data["T"][data.diff()["C"].idxmin()] )
            except:
                pass
                
#         print(Ep12_list,T)
        plt.plot(Ep12_list,T,label="Ee2e=%g"%Ee2e)
        #plt.title("stepcool: Ee2e=%g"%i)
        plt.xlabel("Ep12")
        plt.ylabel("Tm")
    plt.legend()
    plt.show()
#         5*Ep1()
    #     plt.plot(data["T"],data["C"])
#     plt.show()
# Out:
# 4 0.4 2.02
# 4 0.6 2.03
# 4 0.8 2.14
# 4 1 2.25
# 4 1.2 4.76
# 6 0.4 2.52
# 6 0.6 2.63
# 6 0.8 2.64
# 6 1 5.0
# 6 1.2 3.66
# 8 0.4 3.17
# 8 0.6 3.08
# 8 0.8 3.19
# 8 1 3.35
# 8 1.2 3.71
# 12 0.4 4.22
# 12 0.6 4.28
# 12 0.8 4.79
# 12 1 4.75
# 12 1.2 7.16
# 4 0.4 1.57
# 4 0.6 1.63
# 4 0.8 1.79
# 4 1 1.85
# 4 1.2 1.86
# 6 0.4 2.12
# 6 0.6 2.18
# 6 0.8 2.29
# 6 1 2.45
# 6 1.2 2.61
# 8 0.4 2.72
# 8 0.6 2.68
# 8 0.8 2.74
# 8 1 2.75
# 8 1.2 3.06
# 12 0.4 3.77
# 12 0.6 3.63
# 12 0.8 3.79
# 12 1 4.2
# 12 1.2 4.61

# %%
for Ep2 in [0.4,0.2]:

    for Ee2e in [4,6,8,12]:
        T=[]
        Ep12_list=[]
        for Ep12 in np.arange(0.4,1.3,0.2):
            
            try:
                data = pd.read_csv("/home/hcooh/fastdata/IC_stepcoolingless/Ep2=%gEp12=%gEe2e=%d/length"%(Ep2,Ep12,Ee2e),header=None,sep="\t",names=["T","C","C2"])
                Ep12_list.append(Ep12)
                T.append(data["T"][data.diff()["C"].idxmin()])
                print("%g"%Ee2e,"%g"%Ep12,data["T"][data.diff()["C"].idxmin()] )
            except:
                pass
                
#         print(Ep12_list,T)
        plt.plot(Ep12_list,T,label="Ee2e=%g"%Ee2e)
        #plt.title("stepcool: Ee2e=%g"%i)
        plt.xlabel("Ep12")
        plt.ylabel("Tm")
    plt.legend()
    plt.show()
#         5*Ep1()
    #     plt.plot(data["T"],data["C"])
#     plt.show()
# Out:
# 4 0.4 2.02
# 4 0.6 2.03
# 4 0.8 2.14
# 4 1 2.25
# 4 1.2 3.41
# 6 0.4 2.27
# 6 0.6 2.63
# 6 0.8 2.59
# 6 1 2.95
# 6 1.2 3.31
# 8 0.4 2.87
# 8 0.6 3.08
# 8 0.8 3.19
# 8 1 3.35
# 8 1.2 3.71
# 12 0.4 4.37
# 12 0.6 5.08
# 12 0.8 4.39
# 12 1 5.35
# 12 1.2 5.31
# 4 0.4 1.57
# 4 0.6 1.68
# 4 0.8 1.84
# 4 1 2.1
# 4 1.2 2.41
# 6 0.4 2.12
# 6 0.6 2.18
# 6 0.8 2.34
# 6 1 2.4
# 6 1.2 2.56
# 8 0.4 2.72
# 8 0.6 2.63
# 8 0.8 2.69
# 8 1 2.8
# 8 1.2 3.06
# 12 0.4 3.77
# 12 0.6 3.63
# 12 0.8 3.74
# 12 1 4.0
# 12 1.2 4.21

# %%
# Tlist=[]
# maxlist=[]
for T in np.arange(1.2,2.5,0.2):
    data = pd.read_csv("/home/hcooh/fastdata/eccdata_ep1/2020-11-19/Ep2=0.2Ep12=%gEe2e=6T=%g/crystility"%(1.2,T),header=None,sep="\t",names=["i","c"])
#     print(0.6,"%g"%T,data["aver"].max())
#     Tlist.append(T)
#     maxlist.append(data["aver"].max())
    plt.plot(data["i"],data["c"],label="T=%g"%T)
    plt.ylabel("crystallinity")
    plt.xlabel("MC cycles")
plt.legend()
plt.savefig("crystal_T=%g.png"%T)
#     plt.show()
# plt.plot(Tlist,maxlist)
# plt.show()

# %%
# for Ep12 in np.arange(0.6,1.0,0.2):
Tlist=[]
maxlist=[]
for T in np.arange(1.2,2.5,0.2):
    data = pd.read_csv("/home/hcooh/fastdata/"
                       "eccdata_ep1/2020-11-19/Ep2=0.2Ep12=%gEe2e=6T=%g/length"%
                       (0.4,T),header=None,sep="\t",names=["i","max","aver"])
    print(0.4,"%g"%T,data["aver"].max())
    Tlist.append(T)
    maxlist.append(data["aver"].max())
    
    plt.plot(data["i"],data["aver"],label="Ep12=%g"%T)
# plt.title("T=%g"%T)

plt.ylabel("aver length")
plt.xlabel("MC cycle")
plt.legend()
plt.savefig("length_T=%g.png"%T)
#     plt.show()''
plt.figure()
plt.xlabel("T")
plt.ylabel("aver length")
plt.plot(Tlist,maxlist)
plt.show()
#         os.pause()
#         print(0.35*i+3*j)
# Out:
# 0.4 1.2 15.4
# 0.4 1.4 13.36
# 0.4 1.6 15.28
# 0.4 1.8 14.0
# 0.4 2 9.55556
# 0.4 2.2 4.40909
# 0.4 2.4 1.31818

# %%
# Tlist=[]
# maxlist=[]
for T in np.arange(0.5,2.5,0.2):
    data = pd.read_csv("/home/hcooh/projects/float_crystal/data/eccdata_ep1/2020-11-16/Ep2=0.2Ep12=%gEe2e=6T=%g/crystility"%(0.8,T)
                       ,header=None,sep="\t",names=["i","c"])
#     print(0.6,"%g"%T,data["aver"].max())
#     Tlist.append(T)
#     maxlist.append(data["aver"].max())
    plt.plot(data["i"],data["c"],label="T=%g"%T)
    plt.ylabel("crystallinity")
    plt.xlabel("MC cycles")
plt.legend()
plt.savefig("crystal_T=%g.png"%T)
#     plt.show()
# plt.plot(Tlist,maxlist)
# plt.show()
