# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
for i in range(4,11,2):
    for j in np.arange(0.2,1.1,0.2):
        data = pd.read_csv("./data/datastepcool/2020-11-8/Ep2=%gEe2e=%d/crystility"%(j,i),header=None,sep="\t",names=["T","C"])
        print("%g"%i,"%g"%j,data["T"][data.diff()["C"].idxmin()] )
        print("%g"%(0.3*i+2.5*j))
#         5*Ep1()
    #     plt.plot(data["T"],data["C"])
#     plt.show()
# Out:
# 4 0.2 1.7
# 1.7
# 4 0.4 2.1
# 2.2
# 4 0.6 2.6
# 2.7
# 4 0.8 3.1
# 3.2
# 4 1 3.5
# 3.7
# 6 0.2 2.2
# 2.3
# 6 0.4 2.7
# 2.8
# 6 0.6 3.2
# 3.3
# 6 0.8 3.7
# 3.8
# 6 1 4.1
# 4.3
# 8 0.2 2.8
# 2.9
# 8 0.4 3.3
# 3.4
# 8 0.6 3.8
# 3.9
# 8 0.8 4.2
# 4.4
# 8 1 4.6
# 4.9
# 10 0.2 3.5
# 3.5
# 10 0.4 4.0
# 4
# 10 0.6 4.4
# 4.5
# 10 0.8 4.9
# 5
# 10 1 4.8
# 5.5

# %%
for i in range(4,8,2):
    for j in np.arange(0.2,1.1,0.2):
        data = pd.read_csv("./data/datastepheat/2020-11-7/Ep2=%gEe2e=%d/crystility"%(j,i),header=None,sep="\t",names=["T","C"])
        print("%g"%i,"%g"%j,data["T"][data.diff()["C"].idxmin()] )
        print("%g"%(0.35*i+3*j))
#         5*Ep1()
    #     plt.plot(data["T"],data["C"])
#     plt.show()
# Out:
# 4 0.2 2.0
# 2
# 4 0.4 2.6
# 2.6
# 4 0.6 3.1
# 3.2
# 4 0.8 3.7
# 3.8
# 4 1 4.2
# 4.4
# 6 0.2 2.8
# 2.7
# 6 0.4 3.3
# 3.3
# 6 0.6 3.8
# 3.9
# 6 0.8 4.4
# 4.5
# 6 1 5.0
# 5.1

# %%
# for Ep12 in np.arange(0.6,1.0,0.2):
Tlist=[]
maxlist=[]
for T in np.arange(0.5,2.5,0.2):
    data = pd.read_csv("/home/hcooh/projects/float_crystal/data/eccdata_ep1/2020-11-16/Ep2=0.2Ep12=%gEe2e=6T=%g/length"%(0.6,T),header=None,sep="\t",names=["i","max","aver"])
    print(0.6,"%g"%T,data["aver"].max())
    Tlist.append(T)
    maxlist.append(data["aver"].max())
    plt.plot(data["i"],data["aver"])
    plt.show()
plt.plot(Tlist,maxlist)
plt.show()
#         os.pause()
#         print(0.35*i+3*j)
# Out:
# 0.6 0.5 5.59375
# 0.6 0.7 10.0938
# 0.6 0.9 10.0
# 0.6 1.1 17.4375
# 0.6 1.3 23.5
# 0.6 1.5 24.7812
# 0.6 1.7 27.0
# 0.6 1.9 24.0938
# 0.6 2.1 22.0323
# 0.6 2.3 1.29167

# %%
# Tlist=[]
# maxlist=[]
for T in np.arange(0.5,2.5,0.2):
    data = pd.read_csv("/home/hcooh/projects/float_crystal/data/eccdata_ep1/2020-11-16/Ep2=0.2Ep12=%gEe2e=6T=%g/crystility"%(0.6,T),header=None,sep="\t",names=["i","c"])
#     print(0.6,"%g"%T,data["aver"].max())
#     Tlist.append(T)
#     maxlist.append(data["aver"].max())
    plt.plot(data["i"],data["c"])
    plt.ylabel("crystallinity")
    plt.xlabel("MC cycle")
    plt.show()
# plt.plot(Tlist,maxlist)
# plt.show()

# %%
# for Ep12 in np.arange(0.6,1.0,0.2):
Tlist=[]
maxlist=[]
for T in np.arange(0.5,2.5,0.2):
    data = pd.read_csv("/home/hcooh/projects/float_crystal/data/eccdata_ep1/2020-11-16/Ep2=0.2Ep12=%gEe2e=6T=%g/length"%(0.8,T),header=None,sep="\t",names=["i","max","aver"])
    print(0.8,"%g"%T,data["aver"].max())
    Tlist.append(T)
    maxlist.append(data["aver"].max())
    plt.plot(data["i"],data["aver"])
    plt.show()
plt.plot(Tlist,maxlist)
plt.show()
#         os.pause()
#         print(0.35*i+3*j)
# Out:
# 0.8 0.5 5.5625
# 0.8 0.7 9.5625
# 0.8 0.9 10.9062
# 0.8 1.1 15.7188
# 0.8 1.3 20.1562
# 0.8 1.5 23.9688
# 0.8 1.7 24.875
# 0.8 1.9 24.875
# 0.8 2.1 26.9375
# 0.8 2.3 1.4
