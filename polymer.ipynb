# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
1.5/0.8
# Out:
# 1.875

# %%
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'


for Ep2 in [0.4,0.2]:
    plt.figure(figsize=(4, 3), dpi=460)
    for Ee2e in [4,6,8]:
        T=[]
        Ep12_list=[]
        for Ep12 in np.arange(0.4,1.3,0.2):
            data = pd.read_csv("/home/hcooh/fastdata/IC_data/IC_stepheating10/Ep2=%gEp12=%gEe2e=%d/crystility"%(Ep2,Ep12,Ee2e),header=None,sep="\t",names=["T","C"])
            Ep12_list.append(Ep12)
#             T.append(data["T"][data.diff()["C"].idxmin()])
#             print("%g"%Ee2e,"%g"%Ep12,data["T"][data.diff()["C"].idxmin()] )
#         print("%g"%(0.3*i+2.5*j))
        plt.plot(Ep12_list,T,label="Ee2e=%g"%Ee2e)
        #plt.title("stepcool: Ee2e=%g"%i)
        plt.xlabel("${Ep_{12}}$", fontdict={'family' : 'Times New Roman', 'size':8})
        plt.ylabel("${T_m}$", fontdict={'family' : 'Times New Roman', 'size':8})
        plt.xticks(fontproperties = 'Times New Roman', fontsize=8)
        plt.yticks(np.arange(0, 6, 1), fontproperties = 'Times New Roman', fontsize=8)
        plt.legend(loc='lower right', prop={'family':'Times New Roman', 'size':5})
# 图上的legend，记住字体是要用prop以字典形式设置的，而且字的大小是size不是fontsize，这个容易和xticks的命令弄混

        plt.title('${Ep_2=0.2}$', fontdict={'family' : 'Times New Roman', 'size':8})
# 指定图上标题的字体及大小
    plt.savefig('./test.svg', dpi=300, bbox_inches="tight",format='svg')
    plt.show()
#         5*Ep1()
    #     plt.plot(data["T"],data["C"])
#     plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-74a9d4c89e10> in <module>
#      14 #             print("%g"%Ee2e,"%g"%Ep12,data["T"][data.diff()["C"].idxmin()] )
#      15 #         print("%g"%(0.3*i+2.5*j))
# ---> 16         plt.plot(Ep12_list,T,label="Ee2e=%g"%Ee2e)
#      17         #plt.title("stepcool: Ee2e=%g"%i)
#      18         plt.xlabel("${Ep_{12}}$", fontdict={'family' : 'Times New Roman', 'size':8})
#
# ~/miniconda3/envs/py_crystal/lib/python3.8/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
#    2842         **({"data": data} if data is not None else {}), **kwargs)
#
# ...

# %%
for Ep2 in [0.4,0.2]:

    for Ee2e in [4,6,8,12]:
        T=[]
        Ep12_list=[]
        for Ep12 in np.arange(0.4,1.3,0.2):
            
            try:
                data = pd.read_csv("/home/hcooh/fastdata/IC_stepcoolingless/Ep2=%gEp12=%gEe2e=%d/crystility"%(Ep2,Ep12,Ee2e),header=None,sep="\t",names=["T","C"])
                Ep12_list.append(Ep12)
                T.append(data["T"][data.diff()["C"].idxmin()])
                print("%g"%Ee2e,"%g"%Ep12,data["T"][data.diff()["C"].idxmin()] )
            except:
                pass
                
#         print(Ep12_list,T)
        plt.plot(Ep12_list,T,label="Ee2e=%g"%Ee2e)
        #plt.title("stepcool: Ee2e=%g"%i)
        plt.xlabel("Ep12")
        plt.ylabel("Tm")
    plt.legend()
    plt.show()
#         5*Ep1()
    #     plt.plot(data["T"],data["C"])
#     plt.show()

# %%
for Ep2 in [0.4,0.2]:

    for Ee2e in [4,6,8,12]:
        T=[]
        Ep12_list=[]
        for Ep12 in np.arange(0.4,1.3,0.2):
            
            try:
                data = pd.read_csv("/home/hcooh/fastdata/IC_stepcoolingless/Ep2=%gEp12=%gEe2e=%d/length"%(Ep2,Ep12,Ee2e),header=None,sep="\t",names=["T","C","C2"])
                Ep12_list.append(Ep12)
                T.append(data["T"][data.diff()["C"].idxmin()])
                print("%g"%Ee2e,"%g"%Ep12,data["T"][data.diff()["C"].idxmin()] )
            except:
                pass
                
#         print(Ep12_list,T)
        plt.plot(Ep12_list,T,label="Ee2e=%g"%Ee2e)
        #plt.title("stepcool: Ee2e=%g"%i)
        plt.xlabel("Ep12")
        plt.ylabel("Tm")
    plt.legend()
    plt.show()
#         5*Ep1()
    #     plt.plot(data["T"],data["C"])
#     plt.show()

# %%
# Tlist=[]
# maxlist=[]
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.figure(figsize=(4, 3), dpi=460)
for T in np.arange(1.1,2.5,0.2):
    data = pd.read_csv("/home/hcooh/fastdata/eccdata_ep1/2020-11-16/Ep2=0.2Ep12=%gEe2e=6T=%g/crystility"%(1,T),header=None,sep="\t",names=["i","p","s"])
#     print(0.6,"%g"%T,data["aver"].max())
#     Tlist.append(T)
#     maxlist.append(data["aver"].max())
    plt.plot(data["i"],data["s"]/(13888),label="T=%g"%T)
    plt.ylabel("crystallinity of urea", fontdict={'family' : 'Times New Roman', 'size':8})
    plt.xlabel("MC cycles", fontdict={'family' : 'Times New Roman', 'size':8})
    plt.xticks(fontproperties = 'Times New Roman', fontsize=8)
    plt.yticks(fontproperties = 'Times New Roman', fontsize=8)
plt.legend(loc='lower right', prop={'family':'Times New Roman', 'size':8})
plt.savefig("crystal_T=%g.png"%T)
#     plt.show()
# plt.plot(Tlist,maxlist)
# plt.show()
# Out:
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.

# %%
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.rc("font", family='Times New Roman')
plt.figure(figsize=(4, 3), dpi=460)
for T in np.arange(1.1,2.5,0.2):
    data = pd.read_csv("/home/hcooh/fastdata/eccdata_ep1/2020-11-16/Ep2=0.2Ep12=%gEe2e=6T=%g/crystility"%(1,T),header=None,sep="\t",names=["i","p","s"])
#     print(0.6,"%g"%T,data["aver"].max())
#     Tlist.append(T)
#     maxlist.append(data["aver"].max())
    plt.plot(data["i"],data["p"]/(27*32),label="T=%g"%T)
    plt.ylabel("crystallinity of polymer")#, fontdict={'family' : 'Times New Roman', 'size':8})
    plt.xlabel("MC cycles")# fontdict={'family' : 'Times New Roman', 'size':8})
#     plt.xticks(fontproperties = 'Times New Roman', fontsize=8)
#     plt.yticks(fontproperties = 'Times New Roman', fontsize=8)
# plt.legend(loc='lower right', prop={'family':'Times New Roman', 'size':8})
plt.savefig("crystal_T=%g.png"%T)

# %%
# for Ep12 in np.arange(0.6,1.0,0.2):
Tlist=[]
maxlist=[]
for T in np.arange(1.1,2.5,0.2):
    data = pd.read_csv("/home/hcooh/fastdata/"
                       "eccdata_ep1/2020-11-16/Ep2=0.2Ep12=%gEe2e=6T=%g/length"%
                       (1,T),header=None,sep="\t",names=["i","max","aver"])
    Tlist.append(T)
    maxlist.append(data["aver"].max())
    
    plt.plot(data["i"],data["aver"],label="${T=%g}$"%T)
# plt.title("T=%g"%T)

plt.ylabel("average extended length")
plt.xlabel("MC cycles")
plt.legend()
plt.savefig("length_T=%g.png"%T)
#     plt.show()''
plt.figure(figsize=(4, 3), dpi=460)
plt.xlabel("T",fontdict={'family' : 'Times New Roman', 'size':8})
plt.ylabel("average extended length/length",fontdict={'family' : 'Times New Roman', 'size':8})
plt.plot(Tlist,np.asarray(maxlist)/27,"s--")
plt.xticks(fontproperties = 'Times New Roman', fontsize=8)
plt.yticks(fontproperties = 'Times New Roman', fontsize=8)
plt.show()
#         os.pause()
#         print(0.35*i+3*j)

# %%
# Tlist=[]
# maxlist=[]
for T in np.arange(1.1,2.5,0.2):
    data = pd.read_csv("/home/hcooh/projects/float_crystal/data/eccdata_ep1/2020-11-16/Ep2=0.2Ep12=%gEe2e=6T=%g/crystility"%(0.8,T)
                       ,header=None,sep="\t",names=["i","c"])
#     print(0.6,"%g"%T,data["aver"].max())
#     Tlist.append(T)
#     maxlist.append(data["aver"].max())
    plt.plot(data["i"],data["c"],label="T=%g"%T)
    plt.ylabel("crystallinity")
    plt.xlabel("MC cycles")
plt.legend()
plt.savefig("crystal_T=%g.png"%T)
#     plt.show()
# plt.plot(Tlist,maxlist)
# plt.show()

# %%
np.log(24)-1

# %%
# Tlist=[]
# maxlist=[]
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.figure(figsize=(4, 3), dpi=460)
for T in np.arange(1.1,2.5,0.2):
    data = pd.read_csv("/home/hcooh/fastdata/eccdata_ep1/2020-11-16/Ep2=0.2Ep12=%gEe2e=6T=%g/length"%(1,T),header=None,sep="\t",names=["i","m","s"])
#     print(0.6,"%g"%T,data["aver"].max())
#     Tlist.append(T)
#     maxlist.append(data["aver"].max())
    plt.plot(data["i"],data["s"]/(27),label="T=%g"%T)
    plt.ylabel("average extended length/length", fontdict={'family' : 'Times New Roman', 'size':8})
    plt.xlabel("MC cycles", fontdict={'family' : 'Times New Roman', 'size':8})
    plt.xticks(fontproperties = 'Times New Roman', fontsize=8)
    plt.yticks(fontproperties = 'Times New Roman', fontsize=8)
plt.legend(loc='lower right', prop={'family':'Times New Roman', 'size':5})
plt.savefig("crystal_T=%g.png"%T)
#     plt.show()
# plt.plot(Tlist,maxlist)
# plt.show()

# %%
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.figure(figsize=(4, 3), dpi=460)
for T in np.arange(1.1,2.5,0.2):
    data = pd.read_csv("/home/hcooh/fastdata/eccdata_ep1/2020-11-16/Ep2=0.2Ep12=%gEe2e=6T=%g/length"%(1,T),header=None,sep="\t",names=["i","m","s"])
#     print(0.6,"%g"%T,data["aver"].max())
#     Tlist.append(T)
#     maxlist.append(data["aver"].max())
    plt.plot(data["i"],data["m"]/(27),label="T=%g"%T)
    plt.ylabel("max extended length/length", fontdict={'family' : 'Times New Roman', 'size':8})
    plt.xlabel("MC cycles", fontdict={'family' : 'Times New Roman', 'size':8})
    plt.xticks(fontproperties = 'Times New Roman', fontsize=8)
    plt.yticks(fontproperties = 'Times New Roman', fontsize=8)
plt.legend(loc='lower right', prop={'family':'Times New Roman', 'size':5})
plt.savefig("crystal_T=%g.png"%T)
