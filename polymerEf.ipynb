# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
for Ep2 in [0.2]:
    for Ee2e in [4,6,8]:
        for Ep12 in np.arange(0.6,1.3,0.2):
            plt.figure(figsize=(4, 3), dpi=460)
            for T in np.arange(0.1,0.6,0.1):
                Tm=0.3 * Ee2e + 2.5 * Ep2
                Ttrue=Tm+T
                data = pd.read_csv("/home/hcooh/fastdata/IC_data/IC_isothermal_less/2020-12-14/Ep2=%gEp12=%gEe2e=%dT=%g/length"%(Ep2,Ep12,Ee2e,T),header=None,sep="\t",names=["MCs","pc","sc"])
#         print("%g"%(0.3*i+2.5*j))
                plt.plot(data["MCs"],data["sc"]/(36),label="T=%g"%Ttrue)
#                 plt.plot(data["MCs"],data["sc"]/(27900),label="T=%g"%Ttrue)
            plt.xlabel("MC cycles",fontdict={'family' : 'Times New Roman', 'size':8})
            plt.ylabel("average extended length/length",fontdict={'family' : 'Times New Roman', 'size':8})
            plt.title("Ee2e=%d,${Ep_{12}=%g}$"%(Ee2e,Ep12), fontdict={'family' : 'Times New Roman', 'size':8})
            plt.xticks(fontproperties = 'Times New Roman', fontsize=8)
            plt.yticks(fontproperties = 'Times New Roman', fontsize=8)
            plt.legend(loc='lower right', prop={'family':'Times New Roman', 'size':5})
            plt.show()


#         5*Ep1()
    #     plt.plot(data["T"],data["C"])
#     plt.show()

# %%
for Ep2 in [0.2]:
    for Ee2e in [4,6,8]:
        for Ep12 in np.arange(0.6,1.3,0.2):
            for T in np.arange(0.1,0.6,0.1):
                Tm=0.3 * Ee2e + 2.5 * Ep2
                Ttrue=Tm+T
                data = pd.read_csv("/home/hcooh/fastdata/IC_isothermal_less/2020-12-14/Ep2=%gEp12=%gEe2e=%dT=%g/length"%(Ep2,Ep12,Ee2e,T),header=None,sep="\t",names=["MCs","max","aver"])
#         print("%g"%(0.3*i+2.5*j))
                plt.plot(data["MCs"],data["aver"],label="T=%g"%Ttrue)
            plt.xlabel("MCs")
            plt.ylabel("aver extended length")
            plt.title("Ep2=%gEe2e=%d,Ep12=%g"%(Ep2,Ee2e,Ep12))
            plt.legend()
            plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-ccbf28892438> in <module>
#       5                 Tm=0.3 * Ee2e + 2.5 * Ep2
#       6                 Ttrue=Tm+T
# ----> 7                 data = pd.read_csv("/home/hcooh/fastdata/IC_isothermal_less/2020-12-14/Ep2=%gEp12=%gEe2e=%dT=%g/length"%(Ep2,Ep12,Ee2e,T),header=None,sep="\t",names=["MCs","max","aver"])
#       8 #         print("%g"%(0.3*i+2.5*j))
#       9                 plt.plot(data["MCs"],data["aver"],label="T=%g"%Ttrue)
#
# ...

# %%
for Ep2 in [0.2]:
    for Ee2e in [4,6,8]:
        for Ep12 in np.arange(0.6,1.3,0.2):
            for T in np.arange(0.1,0.6,0.1):
                Tm=0.3 * Ee2e + 2.5 * Ep2
                Ttrue=Tm+T
                data = pd.read_csv("/home/hcooh/fastdata/IC_isothermal_less/2020-12-14/Ep2=%gEp12=%gEe2e=%dT=%g/length"%(Ep2,Ep12,Ee2e,T),header=None,sep="\t",names=["MCs","max","aver"])
#         print("%g"%(0.3*i+2.5*j))
                plt.plot(data["MCs"],data["max"],label="T=%g"%Ttrue)
            plt.xlabel("MCs")
            plt.ylabel("max extended length")
            plt.title("Ee2e=%d,Ep12=%g"%(Ee2e,Ep12))
            plt.legend()
            plt.show()

# %%
for Ep2 in [0.2]:
    for Ee2e in [4,6,8]:
        for Ep12 in np.arange(0.6,0.9,0.2):
            for T in np.arange(0.11,0.2,0.01):
                Tm=0.3 * Ee2e + 2.5 * Ep2
                Ttrue=Tm+T
                try:
                    data = pd.read_csv("/home/hcooh/fastdata/IC_isothermal_less/2020-12-15/Ep2=%gEp12=%gEe2e=%dT=%g/length"%(Ep2,Ep12,Ee2e,T),header=None,sep="\t",names=["MCs","max","aver"])
#         print("%g"%(0.3*i+2.5*j))
                except:
                    continue
                plt.plot(data["MCs"],data["max"],label="T=%g"%Ttrue)
            plt.xlabel("MCs")
            plt.ylabel("max extended length")
            plt.title("Ee2e=%d,Ep12=%g"%(Ee2e,Ep12))
            plt.legend()
            plt.show()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
for Ep2 in [0.2]:
    for Ee2e in [4,6,8]:
        for Ep12 in np.arange(0.6,0.9,0.2):
            for T in np.arange(0.11,0.2,0.01):
                Tm=0.3 * Ee2e + 2.5 * Ep2
                Ttrue=Tm+T
                data = pd.read_csv("/home/hcooh/fastdata/IC_isothermal_less/2020-12-15/Ep2=%gEp12=%gEe2e=%dT=%g/length"%(Ep2,Ep12,Ee2e,T),header=None,sep="\t",names=["MCs","max","aver"])
#         print("%g"%(0.3*i+2.5*j))
                plt.plot(data["MCs"],data["aver"],label="T=%g"%Ttrue)
            plt.xlabel("MCs")
            plt.ylabel("aver extended length")
            plt.title("Ee2e=%d,Ep12=%g"%(Ee2e,Ep12))
            plt.legend()
            plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-8225a6ba9fa2> in <module>
#       5                 Tm=0.3 * Ee2e + 2.5 * Ep2
#       6                 Ttrue=Tm+T
# ----> 7                 data = pd.read_csv("/home/hcooh/fastdata/IC_isothermal_less/2020-12-15/Ep2=%gEp12=%gEe2e=%dT=%g/length"%(Ep2,Ep12,Ee2e,T),header=None,sep="\t",names=["MCs","max","aver"])
#       8 #         print("%g"%(0.3*i+2.5*j))
#       9                 plt.plot(data["MCs"],data["aver"],label="T=%g"%Ttrue)
#
# ...

# %%
for Ep2 in [0.2]:
    for Ee2e in [4,6,8]:
        for Ep12 in np.arange(0.6,0.9,0.2):
            for T in np.arange(0.11,0.2,0.01):
                Tm=0.3 * Ee2e + 2.5 * Ep2
                Ttrue=Tm+T
                data = pd.read_csv("/home/hcooh/fastdata/IC_isothermal_less/2020-12-15/Ep2=%gEp12=%gEe2e=%dT=%g/crystility"%(Ep2,Ep12,Ee2e,T),header=None,sep="\t",names=["MCs","C"])
#         print("%g"%(0.3*i+2.5*j))
                plt.plot(data["MCs"],data["C"],label="T=%g"%Ttrue)
            plt.xlabel("MCs")
            plt.ylabel("crystallinity")
            plt.title("Ee2e=%d,Ep12=%g"%(Ee2e,Ep12))
            plt.legend()
            plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-22-a63730f8ea8c> in <module>
#       5                 Tm=0.3 * Ee2e + 2.5 * Ep2
#       6                 Ttrue=Tm+T
# ----> 7                 data = pd.read_csv("/home/hcooh/fastdata/IC_isothermal_less/2020-12-15/Ep2=%gEp12=%gEe2e=%dT=%g/crystility"%(Ep2,Ep12,Ee2e,T),header=None,sep="\t",names=["MCs","C"])
#       8 #         print("%g"%(0.3*i+2.5*j))
#       9                 plt.plot(data["MCs"],data["C"],label="T=%g"%Ttrue)
#
# ...

# %%
# Tlist=[]
# maxlist=[]
for T in np.arange(0.5,2.5,0.2):
    data = pd.read_csv("/home/hcooh/fastdata/IC_stepcoolingless/Ep2=0.2Ep12=%gEe2e=6T=%g/crystility"%(0.4,T),header=None,sep="\t",names=["i","c"])
#     print(0.6,"%g"%T,data["aver"].max())
#     Tlist.append(T)
#     maxlist.append(data["aver"].max())
    plt.plot(data["i"],data["c"],label="T=%g"%T)
    plt.ylabel("crystallinity")
    plt.xlabel("MC cycles")
plt.legend()
plt.savefig("crystal_T=%g.png"%T)
#     plt.show()
# plt.plot(Tlist,maxlist)
# plt.show()

# %%
# for Ep12 in np.arange(0.6,1.0,0.2):
Tlist=[]
maxlist=[]
for T in np.arange(0.5,2.5,0.2):
    data = pd.read_csv("/home/hcooh/projects/float_crystal/"
                       "data/eccdata_ep1/2020-11-16/Ep2=0.2Ep12=%gEe2e=6T=%g/length"%
                       (0.8,T),header=None,sep="\t",names=["i","max","aver"])
    print(0.8,"%g"%T,data["aver"].max())
    Tlist.append(T)
    maxlist.append(data["aver"].max())
    
    plt.plot(data["i"],data["aver"],label="Ep12=%g"%T)
# plt.title("T=%g"%T)

plt.ylabel("aver length")
plt.xlabel("MC cycle")
plt.legend()
plt.savefig("length_T=%g.png"%T)
#     plt.show()''
plt.figure()
plt.xlabel("T")
plt.ylabel("aver length")
plt.plot(Tlist,maxlist)
plt.show()
#         os.pause()
#         print(0.35*i+3*j)
# Out:
# 0.8 0.5 5.5625
# 0.8 0.7 9.5625
# 0.8 0.9 10.9062
# 0.8 1.1 15.7188
# 0.8 1.3 20.1562
# 0.8 1.5 23.9688
# 0.8 1.7 24.875
# 0.8 1.9 24.875
# 0.8 2.1 26.9375
# 0.8 2.3 1.4

# %%
# Tlist=[]
# maxlist=[]
for T in np.arange(0.5,2.5,0.2):
    data = pd.read_csv("/home/hcooh/projects/float_crystal/data/eccdata_ep1/2020-11-16/Ep2=0.2Ep12=%gEe2e=6T=%g/crystility"%(0.8,T)
                       ,header=None,sep="\t",names=["i","c"])
#     print(0.6,"%g"%T,data["aver"].max())
#     Tlist.append(T)
#     maxlist.append(data["aver"].max())
    plt.plot(data["i"],data["c"],label="T=%g"%T)
    plt.ylabel("crystallinity")
    plt.xlabel("MC cycles")
plt.legend()
plt.savefig("crystal_T=%g.png"%T)
#     plt.show()
# plt.plot(Tlist,maxlist)
# plt.show()

# %%
2/0.8
# Out:
# 2.5

# %%
1.5/4
# Out:
# 0.375

# %%
6*0.375 +2.5
# Out:
# 4.75
